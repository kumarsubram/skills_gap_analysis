# %%
from spark_utils import quick_start
spark = quick_start("TestConnection")
# Out:
# 🚀 Creating Spark session: TestConnection
# 📡 Connecting to: spark://spark-master:7077
# 🗄️  MinIO endpoint: http://minio:9000
# 🔺 Delta Lake: ENABLED
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/24 05:26:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/06/24 05:26:18 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# ✅ Spark 4.0.0 session created successfully!
# 🔗 Spark UI: http://localhost:4041
# 💡 S3A ready for s3a://delta-lake/ operations
# 🔺 Delta Lake ready for delta table operations!

# %%
df = spark.read.format("delta").load("s3a://delta-lake/bronze/bronze_github_keyword_extractions")
# Out:
# 25/06/24 05:27:45 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties

# %%
df.show(5, truncate=False)
# Out:
# 25/06/24 05:28:01 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +----+---------+--------+----------------------------+-------------+--------------+----------+------------------------+--------------------------+
# |hour|keyword  |mentions|top_repo                    |repo_mentions|event_mentions|date      |source_file             |processing_time           |
# +----+---------+--------+----------------------------+-------------+--------------+----------+------------------------+--------------------------+
# |11  |gpt-4o   |3       |tooniez/autolabel           |1            |27262         |2024-12-31|2024-12-31-batch.json.gz|2025-06-23 15:31:16.322843|
# |11  |gpt-4    |12      |raghusharma1/java-springboot|4            |27262         |2024-12-31|2024-12-31-batch.json.gz|2025-06-23 15:31:16.322843|
# ...
